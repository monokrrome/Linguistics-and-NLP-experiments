# %% [markdown]
# <a href="https://colab.research.google.com/github/monokrrome/Linguistics-and-NLP-experiments/blob/main/Introduction_to_NLP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Introduction to NLP - Tokenization, stop words removal, Stemming, POS Tagging, Lemmatization**

# %% [markdown]
# Natural Language Processing tasks derive much reference for their tasks from the field of Linguistics. Linguistic analysis consist of Phonetics, Morphology, Syntax, Semantics, Discourse and Pragmatics - which form the foundation of NLP tasks.
#
# A body of text or collection of texts that are analyzed and on which operations are performed is called a corpus. The corpus that we will use in this introduction, we use a shortened, modified excerpt from Technical Report on Soil Degradation in Europe: an integrated economic and environmental assessment by G.J. van den Born, B.J. de Haan, D.W. Pearce, A. Howarth. The shortened text is provided in the repository in the form of a .txt file named 'soil.txt'.
#
# In this introduction, I will demonstrate the basics of data preprocessing of a corpus for NLP tasks. The data preprocessing steps will include:
# 1. Tokenization
# 2. Stopwords Removal
# 3. Stemming
# 4. POS Tagging
# 5. Lemmatization
#
#
# We will first install the necessary libraries and packages to the environment.

# %%
# !pip install nltk
# Out:
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (3.8.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk) (1.3.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk) (2023.12.25)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk) (4.66.2)

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %% [markdown]
# **Tokenization**
#
# In simple layman terms, tokenization refers to breaking up of text into smaller units. There are two types of tokenization demonstarted here:
# 1. Word Tokenization - dividing the text into individual words
# 2. Sentence Tokenization - dividing the text into sentences

# %%
from nltk.tokenize import word_tokenize

sentence = "This is a sample tokenization example."
tokens = word_tokenize(sentence)

print(tokens)
# Out:
# ['This', 'is', 'a', 'sample', 'tokenization', 'example', '.']

# %%
from nltk.tokenize import word_tokenize, sent_tokenize

with open("soil.txt", "r+") as soil:
  content = soil.read()
  tokens = word_tokenize(content)
  sentences = sent_tokenize(content)

print("word tokens: ", tokens)
print("\nsentence tokens: ", sentences)
# Out:
# word tokens:  ['The', 'issue', 'of', 'soil', 'degradation', 'ranges', 'from', 'erosion', 'and', 'contamination', 'of', 'the', 'topsoil', 'to', 'overabstraction', 'and', 'contamination', 'of', 'ground', 'water', '.', 'Soil', 'degradation', 'is', 'an', 'issue', 'of', 'growing', 'concern', 'in', 'Europe', ':', '12', '%', 'of', 'total', 'European', 'land', 'area', 'has', 'been', 'affected', 'by', 'water', 'erosion', 'and', 'a', '4', '%', 'by', 'wind', 'erosion', '(', 'Dobris', '+3', ')', '.', 'The', 'loss', 'of', 'fertile', 'soil', 'itself', 'may', 'degrade', 'the', 'productivity', 'of', 'the', 'local', 'agriculture', '.', 'Also', ',', 'the', 'eroded', 'soil', 'being', 'deposed', 'downstream/wind', 'may', 'cause', 'considerable', 'damage', 'to', 'water', 'management', 'systems', 'by', 'filling', 'up', 'water', 'storage', 'reservoirs', '.', 'Flash', 'floods', 'may', 'occur', 'after', 'torrential', 'rains', 'if', 'water-absorbing', 'capacity', 'has', 'been', 'diminished', 'for', 'agri-economic', 'reasons', '.', 'According', 'to', 'the', 'Dobris+3', 'report', 'about', '115', 'million', 'hectares', 'are', 'suffering', 'from', 'water', 'erosion', 'and', '42', 'million', 'hectares', 'from', 'wind', 'erosion', '(', 'EEA', ',', '1998', ')', '.', 'The', 'problem', 'is', 'greatest', 'in', 'the', 'Mediterranean', 'region', 'because', 'of', 'its', 'fragile', 'environmental', 'conditions', ',', 'but', 'problems', 'exist', 'in', 'most', 'European', 'countries', '.', 'Soil', 'erosion', 'is', 'intensified', 'by', 'agricultural', 'intensification', ',', 'but', 'also', 'by', 'land', 'abandonment', 'and', 'forest', 'fires', ',', 'particularly', 'in', 'marginal', 'areas', '.', 'Abatement', 'strategies', ',', 'such', 'as', 'afforestation', ',', 'for', 'combating', 'accelerated', 'soil', 'erosion', 'are', 'lacking', 'in', 'many', 'areas', '.', 'The', 'complexity', 'of', 'soil', 'degradation', 'makes', 'it', 'hard', 'to', 'make', 'a', 'single', 'statement', 'about', 'its', 'underlying', 'causes', '.', 'Though', 'it', 'is', 'generally', 'accepted', 'that', 'soils', 'should', 'be', 'preserved', ',', 'landowners', 'may', 'manage', 'their', 'land', 'unrestrictedly', '.', 'Owners', 'or', 'users', 'of', 'land', 'subject', 'to', 'erosion', 'may', 'have', 'little', 'incentive', 'to', 'control', 'erosion', 'rates', 'if', 'they', 'do', 'not', 'show', 'up', 'clearly', 'in', 'on-site', 'productivity', 'losses', '.', 'Even', 'if', 'there', 'is', 'an', 'underlying', 'trend', 'to', 'such', 'losses', ',', 'they', 'are', 'often', '‘', 'masked', '’', 'by', 'changes', 'in', 'compensating', 'applications', 'of', 'fertiliser', '.', 'Where', 'on-site', 'damage', 'is', 'evident', 'and', 'directly', 'traceable', 'to', 'erosion', ',', 'it', 'will', 'often', '(', 'but', 'far', 'from', 'always', ')', 'be', 'profitable', 'to', 'control', 'the', 'erosion', 'by', 'changing', 'management', 'practices', ',', 'e.g', '.', 'reduced', 'intensity', 'of', 'crops', ',', 'better', 'cover', 'from', 'surrounding', 'vegetation', ',', 'more', 'organic', 'matter', 'in', 'the', 'soil', 'etc', '.', 'The', 'justification', 'for', 'policy', 'interventions', 'tends', 'to', 'come', 'in', 'two', 'contexts', '(', 'a', ')', 'where', 'off-site', 'costs', 'are', 'significant', ',', 'since', 'these', 'will', 'tend', 'to', 'be', 'ignored', 'by', 'landowners', ',', 'and', '(', 'b', ')', 'where', 'the', 'effect', 'of', 'soil', 'erosion', 'is', 'not', 'transparent', 'to', 'the', 'owner', '.', '(', 'a', ')', 'Off-site', 'costs', '.', 'Because', 'of', 'the', 'difficulties', 'of', 'tracing', 'the', '‘', 'life', 'cycle', '’', 'of', 'soil', 'losses', ',', 'it', 'would', 'seem', 'unlikely', 'that', 'it', 'is', 'possible', 'to', 'develop', 'credible', 'economic', 'instruments', 'that', 'penalise', 'poor', 'soil', 'management', 'behaviour', '.', 'Any', 'measures', 'would', 'tend', 'to', 'be', 'fairly', 'broad', 'spectrum', 'and', 'hence', 'not', 'related', 'to', 'specific', 'damage', 'incidence', '.', 'Such', 'broad', 'm ...
#
# sentence tokens:  ['The issue of soil degradation ranges from erosion and contamination of the topsoil to overabstraction and contamination of ground water.', 'Soil degradation is an issue of growing concern in Europe: 12% of total European land area has been affected by water erosion and a 4% by wind erosion (Dobris +3).', 'The loss of fertile soil itself may degrade the productivity of the local agriculture.', 'Also, the eroded soil being deposed downstream/wind may cause considerable damage to water management systems by filling up water storage reservoirs.', 'Flash floods may occur after torrential rains if water-absorbing capacity has been diminished for agri-economic reasons.', 'According to the Dobris+3 report about 115 million hectares are suffering from water erosion and 42 million hectares from wind erosion (EEA, 1998).', 'The problem is greatest in the Mediterranean region because of its fragile environmental conditions, but problems exist in most European countries.', 'Soil erosion is intensified by agricultural intensification, but also by land abandonment and forest fires, particularly in marginal areas.', 'Abatement strategies, such as afforestation, for combating accelerated soil erosion are lacking in many areas.', 'The complexity of soil degradation makes it hard to make a single statement about its underlying causes.', 'Though it is generally accepted that soils should be preserved, landowners may manage their land unrestrictedly.', 'Owners or users of land subject to erosion may have little incentive to control erosion rates if they do not show up clearly in on-site productivity losses.', 'Even if there is an underlying trend to such losses, they are often ‘masked’ by changes in compensating applications of fertiliser.', 'Where on-site damage is evident and directly traceable to erosion, it will often (but far from always) be profitable to control the erosion by changing management practices, e.g.', 'reduced intensity of crops, better cover from surrounding vegetation, more organic matter in the soil etc.', 'The justification for policy interventions tends to come in two contexts (a) where off-site costs are significant, since these will tend to be ignored by landowners, and (b) where the effect of soil erosion is not transparent to the owner.', '(a)\tOff-site costs.', 'Because of the difficulties of tracing the ‘life cycle’ of soil losses, it would seem unlikely that it is possible to develop credible economic instruments that penalise poor soil management behaviour.', 'Any measures would tend to be fairly broad spectrum and hence not related to specific damage incidence.', 'Such broad measures already exist in some countries, e.g.', 'in terms of controls on land drainage, and land use controls.', 'There is, however, a clearer need to adopt economic incentives in some form.', 'Ideally, some tax on erosive technology and on choice of erosive crops (e.g.', 'winter cereals in the UK have led to significant increases in erosion) should be applied.', 'An ‘erosion tax’ is therefore worthy of further investigation.', 'In the meantime, extension of EU Regulation 2078/92 may be appropriate – see below.', '(b)\tOn site costs.', 'Current agri-environmental regulations hold considerable promise as a means of combating soil erosion.', 'Measures include encouragement for organic farming, afforestation, and on- farm crop management changes.', 'Lawrence (1998) cites two case studies from Germany where mulch seeding and catch crops had clearly identifiable impacts on reduced erosion.', 'Lawrence anticipates further improvements under Agenda 2000 because of beef extensification, ‘green’ rural development measures, more agri-environmental measures and more cross-compliance.', 'It also seems clear that on site losses need far more publicity if land owners are genuinely ignoring significant soil losses because of masking effects.', 'EU Regulation 2078/92 permits co-financing by the Commission of extensification measures in agr ...

# %% [markdown]
# **Removal of stop words**
#
# The idea behind the removal of stop words like articles and pronouns is to make information retrieval and classification faster as they don't have a huge impact on the meaningfulness of the document.
#
# The NLTK library in python provides list of stopwords in english language that can help us in this task. The library also has stopwords lists for many languages such as German, Indonesian, Portuguese, and Spanish.

# %%
nltk.download("stopwords")
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

with open("soil.txt", "r+") as soil:
  soilcontent = soil.read()
  words = word_tokenize(soilcontent)
  stop_words = set(stopwords.words("english"))

  filtered_words = [word for word in words if word.lower() not in stop_words]

print("Original Words:", words)
print("Filtered Words:", filtered_words)
# Out:
# Original Words: ['The', 'issue', 'of', 'soil', 'degradation', 'ranges', 'from', 'erosion', 'and', 'contamination', 'of', 'the', 'topsoil', 'to', 'overabstraction', 'and', 'contamination', 'of', 'ground', 'water', '.', 'Soil', 'degradation', 'is', 'an', 'issue', 'of', 'growing', 'concern', 'in', 'Europe', ':', '12', '%', 'of', 'total', 'European', 'land', 'area', 'has', 'been', 'affected', 'by', 'water', 'erosion', 'and', 'a', '4', '%', 'by', 'wind', 'erosion', '(', 'Dobris', '+3', ')', '.', 'The', 'loss', 'of', 'fertile', 'soil', 'itself', 'may', 'degrade', 'the', 'productivity', 'of', 'the', 'local', 'agriculture', '.', 'Also', ',', 'the', 'eroded', 'soil', 'being', 'deposed', 'downstream/wind', 'may', 'cause', 'considerable', 'damage', 'to', 'water', 'management', 'systems', 'by', 'filling', 'up', 'water', 'storage', 'reservoirs', '.', 'Flash', 'floods', 'may', 'occur', 'after', 'torrential', 'rains', 'if', 'water-absorbing', 'capacity', 'has', 'been', 'diminished', 'for', 'agri-economic', 'reasons', '.', 'According', 'to', 'the', 'Dobris+3', 'report', 'about', '115', 'million', 'hectares', 'are', 'suffering', 'from', 'water', 'erosion', 'and', '42', 'million', 'hectares', 'from', 'wind', 'erosion', '(', 'EEA', ',', '1998', ')', '.', 'The', 'problem', 'is', 'greatest', 'in', 'the', 'Mediterranean', 'region', 'because', 'of', 'its', 'fragile', 'environmental', 'conditions', ',', 'but', 'problems', 'exist', 'in', 'most', 'European', 'countries', '.', 'Soil', 'erosion', 'is', 'intensified', 'by', 'agricultural', 'intensification', ',', 'but', 'also', 'by', 'land', 'abandonment', 'and', 'forest', 'fires', ',', 'particularly', 'in', 'marginal', 'areas', '.', 'Abatement', 'strategies', ',', 'such', 'as', 'afforestation', ',', 'for', 'combating', 'accelerated', 'soil', 'erosion', 'are', 'lacking', 'in', 'many', 'areas', '.', 'The', 'complexity', 'of', 'soil', 'degradation', 'makes', 'it', 'hard', 'to', 'make', 'a', 'single', 'statement', 'about', 'its', 'underlying', 'causes', '.', 'Though', 'it', 'is', 'generally', 'accepted', 'that', 'soils', 'should', 'be', 'preserved', ',', 'landowners', 'may', 'manage', 'their', 'land', 'unrestrictedly', '.', 'Owners', 'or', 'users', 'of', 'land', 'subject', 'to', 'erosion', 'may', 'have', 'little', 'incentive', 'to', 'control', 'erosion', 'rates', 'if', 'they', 'do', 'not', 'show', 'up', 'clearly', 'in', 'on-site', 'productivity', 'losses', '.', 'Even', 'if', 'there', 'is', 'an', 'underlying', 'trend', 'to', 'such', 'losses', ',', 'they', 'are', 'often', '‘', 'masked', '’', 'by', 'changes', 'in', 'compensating', 'applications', 'of', 'fertiliser', '.', 'Where', 'on-site', 'damage', 'is', 'evident', 'and', 'directly', 'traceable', 'to', 'erosion', ',', 'it', 'will', 'often', '(', 'but', 'far', 'from', 'always', ')', 'be', 'profitable', 'to', 'control', 'the', 'erosion', 'by', 'changing', 'management', 'practices', ',', 'e.g', '.', 'reduced', 'intensity', 'of', 'crops', ',', 'better', 'cover', 'from', 'surrounding', 'vegetation', ',', 'more', 'organic', 'matter', 'in', 'the', 'soil', 'etc', '.', 'The', 'justification', 'for', 'policy', 'interventions', 'tends', 'to', 'come', 'in', 'two', 'contexts', '(', 'a', ')', 'where', 'off-site', 'costs', 'are', 'significant', ',', 'since', 'these', 'will', 'tend', 'to', 'be', 'ignored', 'by', 'landowners', ',', 'and', '(', 'b', ')', 'where', 'the', 'effect', 'of', 'soil', 'erosion', 'is', 'not', 'transparent', 'to', 'the', 'owner', '.', '(', 'a', ')', 'Off-site', 'costs', '.', 'Because', 'of', 'the', 'difficulties', 'of', 'tracing', 'the', '‘', 'life', 'cycle', '’', 'of', 'soil', 'losses', ',', 'it', 'would', 'seem', 'unlikely', 'that', 'it', 'is', 'possible', 'to', 'develop', 'credible', 'economic', 'instruments', 'that', 'penalise', 'poor', 'soil', 'management', 'behaviour', '.', 'Any', 'measures', 'would', 'tend', 'to', 'be', 'fairly', 'broad', 'spectrum', 'and', 'hence', 'not', 'related', 'to', 'specific', 'damage', 'incidence', '.', 'Such', 'broad',  ...
# Filtered Words: ['issue', 'soil', 'degradation', 'ranges', 'erosion', 'contamination', 'topsoil', 'overabstraction', 'contamination', 'ground', 'water', '.', 'Soil', 'degradation', 'issue', 'growing', 'concern', 'Europe', ':', '12', '%', 'total', 'European', 'land', 'area', 'affected', 'water', 'erosion', '4', '%', 'wind', 'erosion', '(', 'Dobris', '+3', ')', '.', 'loss', 'fertile', 'soil', 'may', 'degrade', 'productivity', 'local', 'agriculture', '.', 'Also', ',', 'eroded', 'soil', 'deposed', 'downstream/wind', 'may', 'cause', 'considerable', 'damage', 'water', 'management', 'systems', 'filling', 'water', 'storage', 'reservoirs', '.', 'Flash', 'floods', 'may', 'occur', 'torrential', 'rains', 'water-absorbing', 'capacity', 'diminished', 'agri-economic', 'reasons', '.', 'According', 'Dobris+3', 'report', '115', 'million', 'hectares', 'suffering', 'water', 'erosion', '42', 'million', 'hectares', 'wind', 'erosion', '(', 'EEA', ',', '1998', ')', '.', 'problem', 'greatest', 'Mediterranean', 'region', 'fragile', 'environmental', 'conditions', ',', 'problems', 'exist', 'European', 'countries', '.', 'Soil', 'erosion', 'intensified', 'agricultural', 'intensification', ',', 'also', 'land', 'abandonment', 'forest', 'fires', ',', 'particularly', 'marginal', 'areas', '.', 'Abatement', 'strategies', ',', 'afforestation', ',', 'combating', 'accelerated', 'soil', 'erosion', 'lacking', 'many', 'areas', '.', 'complexity', 'soil', 'degradation', 'makes', 'hard', 'make', 'single', 'statement', 'underlying', 'causes', '.', 'Though', 'generally', 'accepted', 'soils', 'preserved', ',', 'landowners', 'may', 'manage', 'land', 'unrestrictedly', '.', 'Owners', 'users', 'land', 'subject', 'erosion', 'may', 'little', 'incentive', 'control', 'erosion', 'rates', 'show', 'clearly', 'on-site', 'productivity', 'losses', '.', 'Even', 'underlying', 'trend', 'losses', ',', 'often', '‘', 'masked', '’', 'changes', 'compensating', 'applications', 'fertiliser', '.', 'on-site', 'damage', 'evident', 'directly', 'traceable', 'erosion', ',', 'often', '(', 'far', 'always', ')', 'profitable', 'control', 'erosion', 'changing', 'management', 'practices', ',', 'e.g', '.', 'reduced', 'intensity', 'crops', ',', 'better', 'cover', 'surrounding', 'vegetation', ',', 'organic', 'matter', 'soil', 'etc', '.', 'justification', 'policy', 'interventions', 'tends', 'come', 'two', 'contexts', '(', ')', 'off-site', 'costs', 'significant', ',', 'since', 'tend', 'ignored', 'landowners', ',', '(', 'b', ')', 'effect', 'soil', 'erosion', 'transparent', 'owner', '.', '(', ')', 'Off-site', 'costs', '.', 'difficulties', 'tracing', '‘', 'life', 'cycle', '’', 'soil', 'losses', ',', 'would', 'seem', 'unlikely', 'possible', 'develop', 'credible', 'economic', 'instruments', 'penalise', 'poor', 'soil', 'management', 'behaviour', '.', 'measures', 'would', 'tend', 'fairly', 'broad', 'spectrum', 'hence', 'related', 'specific', 'damage', 'incidence', '.', 'broad', 'measures', 'already', 'exist', 'countries', ',', 'e.g', '.', 'terms', 'controls', 'land', 'drainage', ',', 'land', 'use', 'controls', '.', ',', 'however', ',', 'clearer', 'need', 'adopt', 'economic', 'incentives', 'form', '.', 'Ideally', ',', 'tax', 'erosive', 'technology', 'choice', 'erosive', 'crops', '(', 'e.g', '.', 'winter', 'cereals', 'UK', 'led', 'significant', 'increases', 'erosion', ')', 'applied', '.', '‘', 'erosion', 'tax', '’', 'therefore', 'worthy', 'investigation', '.', 'meantime', ',', 'extension', 'EU', 'Regulation', '2078/92', 'may', 'appropriate', '–', 'see', '.', '(', 'b', ')', 'site', 'costs', '.', 'Current', 'agri-environmental', 'regulations', 'hold', 'considerable', 'promise', 'means', 'combating', 'soil', 'erosion', '.', 'Measures', 'include', 'encouragement', 'organic', 'farming', ',', 'afforestation', ',', 'on-', 'farm', 'crop', 'management', 'changes', '.', 'Lawrence', '(', '1998', ')', 'cites', 'two', 'case', 'studies', 'Germany', 'mulch', 'seeding', 'catch', 'crops', 'clearly', 'identifiable', 'impacts', 'reduced', 'e ...
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %% [markdown]
# **Stemming**
#
# Stemming refers to reducing words to their "stem words". These stem words may not necessarily be actual words as they do not consider linguistic context. By reducing many variations of a word to their stem words, information retrieval or document clustering can be made faster.
#
# We will use a popular stemming algorithm called Porter Stemming which is provided as a function in the NLTK library. IBM explains this algorithm as, 'The Porter stemming algorithm classifies every character in a given token as either a consonant ("c") or vowel ("v"), grouping subsequent consonants as "C" and subsequent vowels as "V." The algorithm thereby represents every word token as a specific combination of consonant and vowel groups. For example, the word therefore is represented as CVCVCVCV, or C(VC)3V, with the exponent representing repetitions of consonant-vowel groups.'

# %%
from nltk.stem import PorterStemmer
from nltk.tokenize import word_tokenize

stemmer = PorterStemmer()
with open("soil.txt", "r+") as soil:
  soilcontent = soil.read()
  words = word_tokenize(soilcontent)
  stemmed_words = [stemmer.stem(word) for word in words]

print(stemmed_words)
# Out:
# ['the', 'issu', 'of', 'soil', 'degrad', 'rang', 'from', 'eros', 'and', 'contamin', 'of', 'the', 'topsoil', 'to', 'overabstract', 'and', 'contamin', 'of', 'ground', 'water', '.', 'soil', 'degrad', 'is', 'an', 'issu', 'of', 'grow', 'concern', 'in', 'europ', ':', '12', '%', 'of', 'total', 'european', 'land', 'area', 'ha', 'been', 'affect', 'by', 'water', 'eros', 'and', 'a', '4', '%', 'by', 'wind', 'eros', '(', 'dobri', '+3', ')', '.', 'the', 'loss', 'of', 'fertil', 'soil', 'itself', 'may', 'degrad', 'the', 'product', 'of', 'the', 'local', 'agricultur', '.', 'also', ',', 'the', 'erod', 'soil', 'be', 'depos', 'downstream/wind', 'may', 'caus', 'consider', 'damag', 'to', 'water', 'manag', 'system', 'by', 'fill', 'up', 'water', 'storag', 'reservoir', '.', 'flash', 'flood', 'may', 'occur', 'after', 'torrenti', 'rain', 'if', 'water-absorb', 'capac', 'ha', 'been', 'diminish', 'for', 'agri-econom', 'reason', '.', 'accord', 'to', 'the', 'dobris+3', 'report', 'about', '115', 'million', 'hectar', 'are', 'suffer', 'from', 'water', 'eros', 'and', '42', 'million', 'hectar', 'from', 'wind', 'eros', '(', 'eea', ',', '1998', ')', '.', 'the', 'problem', 'is', 'greatest', 'in', 'the', 'mediterranean', 'region', 'becaus', 'of', 'it', 'fragil', 'environment', 'condit', ',', 'but', 'problem', 'exist', 'in', 'most', 'european', 'countri', '.', 'soil', 'eros', 'is', 'intensifi', 'by', 'agricultur', 'intensif', ',', 'but', 'also', 'by', 'land', 'abandon', 'and', 'forest', 'fire', ',', 'particularli', 'in', 'margin', 'area', '.', 'abat', 'strategi', ',', 'such', 'as', 'afforest', ',', 'for', 'combat', 'acceler', 'soil', 'eros', 'are', 'lack', 'in', 'mani', 'area', '.', 'the', 'complex', 'of', 'soil', 'degrad', 'make', 'it', 'hard', 'to', 'make', 'a', 'singl', 'statement', 'about', 'it', 'underli', 'caus', '.', 'though', 'it', 'is', 'gener', 'accept', 'that', 'soil', 'should', 'be', 'preserv', ',', 'landown', 'may', 'manag', 'their', 'land', 'unrestrictedli', '.', 'owner', 'or', 'user', 'of', 'land', 'subject', 'to', 'eros', 'may', 'have', 'littl', 'incent', 'to', 'control', 'eros', 'rate', 'if', 'they', 'do', 'not', 'show', 'up', 'clearli', 'in', 'on-sit', 'product', 'loss', '.', 'even', 'if', 'there', 'is', 'an', 'underli', 'trend', 'to', 'such', 'loss', ',', 'they', 'are', 'often', '‘', 'mask', '’', 'by', 'chang', 'in', 'compens', 'applic', 'of', 'fertilis', '.', 'where', 'on-sit', 'damag', 'is', 'evid', 'and', 'directli', 'traceabl', 'to', 'eros', ',', 'it', 'will', 'often', '(', 'but', 'far', 'from', 'alway', ')', 'be', 'profit', 'to', 'control', 'the', 'eros', 'by', 'chang', 'manag', 'practic', ',', 'e.g', '.', 'reduc', 'intens', 'of', 'crop', ',', 'better', 'cover', 'from', 'surround', 'veget', ',', 'more', 'organ', 'matter', 'in', 'the', 'soil', 'etc', '.', 'the', 'justif', 'for', 'polici', 'intervent', 'tend', 'to', 'come', 'in', 'two', 'context', '(', 'a', ')', 'where', 'off-sit', 'cost', 'are', 'signific', ',', 'sinc', 'these', 'will', 'tend', 'to', 'be', 'ignor', 'by', 'landown', ',', 'and', '(', 'b', ')', 'where', 'the', 'effect', 'of', 'soil', 'eros', 'is', 'not', 'transpar', 'to', 'the', 'owner', '.', '(', 'a', ')', 'off-sit', 'cost', '.', 'becaus', 'of', 'the', 'difficulti', 'of', 'trace', 'the', '‘', 'life', 'cycl', '’', 'of', 'soil', 'loss', ',', 'it', 'would', 'seem', 'unlik', 'that', 'it', 'is', 'possibl', 'to', 'develop', 'credibl', 'econom', 'instrument', 'that', 'penalis', 'poor', 'soil', 'manag', 'behaviour', '.', 'ani', 'measur', 'would', 'tend', 'to', 'be', 'fairli', 'broad', 'spectrum', 'and', 'henc', 'not', 'relat', 'to', 'specif', 'damag', 'incid', '.', 'such', 'broad', 'measur', 'alreadi', 'exist', 'in', 'some', 'countri', ',', 'e.g', '.', 'in', 'term', 'of', 'control', 'on', 'land', 'drainag', ',', 'and', 'land', 'use', 'control', '.', 'there', 'is', ',', 'howev', ',', 'a', 'clearer', 'need', 'to', 'adopt', 'econom', 'incent', 'in', 'some', 'form', '.', 'ideal', ',', 'some', 'tax', 'on', 'eros', 'technolog', 'and', 'on', 'choi ...

# %% [markdown]
# **Parts of Speech Tagging - POS Tagging**
#
# As the name suggests, POS tagging assigns different words to the parts of speech. We will be using the Average Perceptron Tagger which is a widely used tagger from the nltk library.

# %%
import nltk
nltk.download('averaged_perceptron_tagger')
from nltk.tokenize import word_tokenize

with open("soil.txt", "r+") as soil:
  soilcontent = soil.read()
  words = word_tokenize(soilcontent)
  tagged_words = nltk.pos_tag(words)
  print(tagged_words)
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [('The', 'DT'), ('issue', 'NN'), ('of', 'IN'), ('soil', 'NN'), ('degradation', 'NN'), ('ranges', 'VBZ'), ('from', 'IN'), ('erosion', 'NN'), ('and', 'CC'), ('contamination', 'NN'), ('of', 'IN'), ('the', 'DT'), ('topsoil', 'NN'), ('to', 'TO'), ('overabstraction', 'NN'), ('and', 'CC'), ('contamination', 'NN'), ('of', 'IN'), ('ground', 'NN'), ('water', 'NN'), ('.', '.'), ('Soil', 'NNP'), ('degradation', 'NN'), ('is', 'VBZ'), ('an', 'DT'), ('issue', 'NN'), ('of', 'IN'), ('growing', 'VBG'), ('concern', 'NN'), ('in', 'IN'), ('Europe', 'NNP'), (':', ':'), ('12', 'CD'), ('%', 'NN'), ('of', 'IN'), ('total', 'JJ'), ('European', 'JJ'), ('land', 'NN'), ('area', 'NN'), ('has', 'VBZ'), ('been', 'VBN'), ('affected', 'VBN'), ('by', 'IN'), ('water', 'NN'), ('erosion', 'NN'), ('and', 'CC'), ('a', 'DT'), ('4', 'CD'), ('%', 'NN'), ('by', 'IN'), ('wind', 'NN'), ('erosion', 'NN'), ('(', '('), ('Dobris', 'NNP'), ('+3', 'NNP'), (')', ')'), ('.', '.'), ('The', 'DT'), ('loss', 'NN'), ('of', 'IN'), ('fertile', 'JJ'), ('soil', 'NN'), ('itself', 'PRP'), ('may', 'MD'), ('degrade', 'VB'), ('the', 'DT'), ('productivity', 'NN'), ('of', 'IN'), ('the', 'DT'), ('local', 'JJ'), ('agriculture', 'NN'), ('.', '.'), ('Also', 'RB'), (',', ','), ('the', 'DT'), ('eroded', 'JJ'), ('soil', 'NN'), ('being', 'VBG'), ('deposed', 'VBN'), ('downstream/wind', 'NN'), ('may', 'MD'), ('cause', 'VB'), ('considerable', 'JJ'), ('damage', 'NN'), ('to', 'TO'), ('water', 'NN'), ('management', 'NN'), ('systems', 'NNS'), ('by', 'IN'), ('filling', 'VBG'), ('up', 'RP'), ('water', 'NN'), ('storage', 'NN'), ('reservoirs', 'NNS'), ('.', '.'), ('Flash', 'NNP'), ('floods', 'NNS'), ('may', 'MD'), ('occur', 'VB'), ('after', 'IN'), ('torrential', 'JJ'), ('rains', 'NNS'), ('if', 'IN'), ('water-absorbing', 'JJ'), ('capacity', 'NN'), ('has', 'VBZ'), ('been', 'VBN'), ('diminished', 'VBN'), ('for', 'IN'), ('agri-economic', 'JJ'), ('reasons', 'NNS'), ('.', '.'), ('According', 'VBG'), ('to', 'TO'), ('the', 'DT'), ('Dobris+3', 'NNP'), ('report', 'NN'), ('about', 'IN'), ('115', 'CD'), ('million', 'CD'), ('hectares', 'NNS'), ('are', 'VBP'), ('suffering', 'VBG'), ('from', 'IN'), ('water', 'NN'), ('erosion', 'NN'), ('and', 'CC'), ('42', 'CD'), ('million', 'CD'), ('hectares', 'NNS'), ('from', 'IN'), ('wind', 'NN'), ('erosion', 'NN'), ('(', '('), ('EEA', 'NNP'), (',', ','), ('1998', 'CD'), (')', ')'), ('.', '.'), ('The', 'DT'), ('problem', 'NN'), ('is', 'VBZ'), ('greatest', 'JJS'), ('in', 'IN'), ('the', 'DT'), ('Mediterranean', 'NNP'), ('region', 'NN'), ('because', 'IN'), ('of', 'IN'), ('its', 'PRP$'), ('fragile', 'JJ'), ('environmental', 'JJ'), ('conditions', 'NNS'), (',', ','), ('but', 'CC'), ('problems', 'NNS'), ('exist', 'VBP'), ('in', 'IN'), ('most', 'JJS'), ('European', 'JJ'), ('countries', 'NNS'), ('.', '.'), ('Soil', 'NNP'), ('erosion', 'NN'), ('is', 'VBZ'), ('intensified', 'VBN'), ('by', 'IN'), ('agricultural', 'JJ'), ('intensification', 'NN'), (',', ','), ('but', 'CC'), ('also', 'RB'), ('by', 'IN'), ('land', 'NN'), ('abandonment', 'NN'), ('and', 'CC'), ('forest', 'JJS'), ('fires', 'NNS'), (',', ','), ('particularly', 'RB'), ('in', 'IN'), ('marginal', 'JJ'), ('areas', 'NNS'), ('.', '.'), ('Abatement', 'NNP'), ('strategies', 'NNS'), (',', ','), ('such', 'JJ'), ('as', 'IN'), ('afforestation', 'NN'), (',', ','), ('for', 'IN'), ('combating', 'VBG'), ('accelerated', 'JJ'), ('soil', 'NN'), ('erosion', 'NN'), ('are', 'VBP'), ('lacking', 'VBG'), ('in', 'IN'), ('many', 'JJ'), ('areas', 'NNS'), ('.', '.'), ('The', 'DT'), ('complexity', 'NN'), ('of', 'IN'), ('soil', 'NN'), ('degradation', 'NN'), ('makes', 'VBZ'), ('it', 'PRP'), ('hard', 'JJ'), ('to', 'TO'), ('make', 'VB'), ('a', 'DT'), ('single', 'JJ'), ('statement', 'NN'), ('about', 'IN'), ('its', 'PRP$'), ('underlying', 'JJ'), ('causes', 'NNS'), ('.', '.'), ('Though', 'IN'), ('it', 'PRP'), ('is', 'VBZ'), ('generally', 'RB'), ('accepted', 'VBN'), ('that', 'IN'), ('soils', 'NNS'), ('should', 'MD'), ('be', 'VB'), ('preserved', 'VBN'), (',', ','), ('landowners', 'NNS ...

# %% [markdown]
# **Lemmatization**
#
# Lemmatization is similar to stemming in that it reduces different variations of the word. However, the variations are mapped to a 'lemma' and the linguistic context and meaning is considered while doing so.

# %%
nltk.download('wordnet')
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer

lemmatizer = WordNetLemmatizer()

with open("soil.txt", "r+") as soil:
  soilcontent = soil.read()
  words = word_tokenize(soilcontent)
  lemmatized_words = [lemmatizer.lemmatize(word) for word in words]

print(lemmatized_words)
# Out:
# ['The', 'issue', 'of', 'soil', 'degradation', 'range', 'from', 'erosion', 'and', 'contamination', 'of', 'the', 'topsoil', 'to', 'overabstraction', 'and', 'contamination', 'of', 'ground', 'water', '.', 'Soil', 'degradation', 'is', 'an', 'issue', 'of', 'growing', 'concern', 'in', 'Europe', ':', '12', '%', 'of', 'total', 'European', 'land', 'area', 'ha', 'been', 'affected', 'by', 'water', 'erosion', 'and', 'a', '4', '%', 'by', 'wind', 'erosion', '(', 'Dobris', '+3', ')', '.', 'The', 'loss', 'of', 'fertile', 'soil', 'itself', 'may', 'degrade', 'the', 'productivity', 'of', 'the', 'local', 'agriculture', '.', 'Also', ',', 'the', 'eroded', 'soil', 'being', 'deposed', 'downstream/wind', 'may', 'cause', 'considerable', 'damage', 'to', 'water', 'management', 'system', 'by', 'filling', 'up', 'water', 'storage', 'reservoir', '.', 'Flash', 'flood', 'may', 'occur', 'after', 'torrential', 'rain', 'if', 'water-absorbing', 'capacity', 'ha', 'been', 'diminished', 'for', 'agri-economic', 'reason', '.', 'According', 'to', 'the', 'Dobris+3', 'report', 'about', '115', 'million', 'hectare', 'are', 'suffering', 'from', 'water', 'erosion', 'and', '42', 'million', 'hectare', 'from', 'wind', 'erosion', '(', 'EEA', ',', '1998', ')', '.', 'The', 'problem', 'is', 'greatest', 'in', 'the', 'Mediterranean', 'region', 'because', 'of', 'it', 'fragile', 'environmental', 'condition', ',', 'but', 'problem', 'exist', 'in', 'most', 'European', 'country', '.', 'Soil', 'erosion', 'is', 'intensified', 'by', 'agricultural', 'intensification', ',', 'but', 'also', 'by', 'land', 'abandonment', 'and', 'forest', 'fire', ',', 'particularly', 'in', 'marginal', 'area', '.', 'Abatement', 'strategy', ',', 'such', 'a', 'afforestation', ',', 'for', 'combating', 'accelerated', 'soil', 'erosion', 'are', 'lacking', 'in', 'many', 'area', '.', 'The', 'complexity', 'of', 'soil', 'degradation', 'make', 'it', 'hard', 'to', 'make', 'a', 'single', 'statement', 'about', 'it', 'underlying', 'cause', '.', 'Though', 'it', 'is', 'generally', 'accepted', 'that', 'soil', 'should', 'be', 'preserved', ',', 'landowner', 'may', 'manage', 'their', 'land', 'unrestrictedly', '.', 'Owners', 'or', 'user', 'of', 'land', 'subject', 'to', 'erosion', 'may', 'have', 'little', 'incentive', 'to', 'control', 'erosion', 'rate', 'if', 'they', 'do', 'not', 'show', 'up', 'clearly', 'in', 'on-site', 'productivity', 'loss', '.', 'Even', 'if', 'there', 'is', 'an', 'underlying', 'trend', 'to', 'such', 'loss', ',', 'they', 'are', 'often', '‘', 'masked', '’', 'by', 'change', 'in', 'compensating', 'application', 'of', 'fertiliser', '.', 'Where', 'on-site', 'damage', 'is', 'evident', 'and', 'directly', 'traceable', 'to', 'erosion', ',', 'it', 'will', 'often', '(', 'but', 'far', 'from', 'always', ')', 'be', 'profitable', 'to', 'control', 'the', 'erosion', 'by', 'changing', 'management', 'practice', ',', 'e.g', '.', 'reduced', 'intensity', 'of', 'crop', ',', 'better', 'cover', 'from', 'surrounding', 'vegetation', ',', 'more', 'organic', 'matter', 'in', 'the', 'soil', 'etc', '.', 'The', 'justification', 'for', 'policy', 'intervention', 'tends', 'to', 'come', 'in', 'two', 'context', '(', 'a', ')', 'where', 'off-site', 'cost', 'are', 'significant', ',', 'since', 'these', 'will', 'tend', 'to', 'be', 'ignored', 'by', 'landowner', ',', 'and', '(', 'b', ')', 'where', 'the', 'effect', 'of', 'soil', 'erosion', 'is', 'not', 'transparent', 'to', 'the', 'owner', '.', '(', 'a', ')', 'Off-site', 'cost', '.', 'Because', 'of', 'the', 'difficulty', 'of', 'tracing', 'the', '‘', 'life', 'cycle', '’', 'of', 'soil', 'loss', ',', 'it', 'would', 'seem', 'unlikely', 'that', 'it', 'is', 'possible', 'to', 'develop', 'credible', 'economic', 'instrument', 'that', 'penalise', 'poor', 'soil', 'management', 'behaviour', '.', 'Any', 'measure', 'would', 'tend', 'to', 'be', 'fairly', 'broad', 'spectrum', 'and', 'hence', 'not', 'related', 'to', 'specific', 'damage', 'incidence', '.', 'Such', 'broad', 'measure', 'already', 'exist', 'in', 'some', 'country', ',', 'e ...
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
